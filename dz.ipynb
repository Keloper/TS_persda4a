# %%
import pandas as pd 
import os

# %%
os.getcwd()
# Out:
# '/Users/ivanbogush/TS_dz'

# %%
df = pd.read_csv('train.csv')
# Out:
# /var/folders/28/sfq_hns161j8ppvs2qwgz6xw0000gn/T/ipykernel_50725/2436019669.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion
# 0   0  2013-01-01         25    103665         7.0         NaN
# 1   1  2013-01-01         25    105574         1.0         NaN
# 2   2  2013-01-01         25    105575         2.0         NaN
# 3   3  2013-01-01         25    108079         1.0         NaN
# 4   4  2013-01-01         25    108701         1.0         NaN

# %%
df.shape
# Out:
# (125497040, 6)
